# %% [markdown]
# # IMPORTS

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset=pd.read_csv("ad_click_dataset.csv")
dataset
# Out:
#         id full_name   age      gender device_type ad_position  \
# 0      670   User670  22.0         NaN     Desktop         Top
# 1     3044  User3044   NaN        Male     Desktop         Top
# 2     5912  User5912  41.0  Non-Binary         NaN        Side
# 3     5418  User5418  34.0        Male         NaN         NaN
# 4     9452  User9452  39.0  Non-Binary         NaN         NaN
# ...    ...       ...   ...         ...         ...         ...
# 9995  8510  User8510   NaN         NaN      Mobile         Top
# 9996  7843  User7843   NaN      Female     Desktop      Bottom
# 9997  3914  User3914   NaN        Male      Mobile        Side
# 9998  7924  User7924   NaN         NaN     Desktop         NaN
# 9999  3056  User3056  44.0        Male      Tablet         Top
#
#      browsing_history time_of_day  click
# 0            Shopping   Afternoon      1
# 1                 NaN         NaN      1
# 2           Education       Night      1
# 3       Entertainment     Evening      1
# ...

# %%
dataset=pd.get_dummies(dataset,drop_first=True)
dataset.dropna(inplace=True)
dataset
# Out:
#         id   age  click  full_name_User100  full_name_User1000  \
# 0      670  22.0      1              False               False
# 2     5912  41.0      1              False               False
# 3     5418  34.0      1              False               False
# 4     9452  39.0      0              False               False
# 6     7808  26.0      1              False               False
# ...    ...   ...    ...                ...                 ...
# 9987  2876  23.0      1              False               False
# 9988  2713  52.0      0              False               False
# 9990  9540  64.0      0              False               False
# 9993   503  43.0      1              False               False
# 9999  3056  44.0      0              False               False
#
#       full_name_User10000  full_name_User1001  full_name_User1002  \
# 0                   False               False               False
# 2                   False               False               False
# ...

# %% [markdown]
# # Data Visualization

# %%
dataset.head()
# Out:
#      id   age  click  full_name_User100  full_name_User1000  \
# 0   670  22.0      1              False               False
# 2  5912  41.0      1              False               False
# 3  5418  34.0      1              False               False
# 4  9452  39.0      0              False               False
# 6  7808  26.0      1              False               False
#
#    full_name_User10000  full_name_User1001  full_name_User1002  \
# 0                False               False               False
# 2                False               False               False
# 3                False               False               False
# 4                False               False               False
# 6                False               False               False
#
#    full_name_User1011  full_name_User1012  ...  device_type_Tablet  \
# 0               False               False  ...               False
# 2               False               False  ...               False
# ...

# %% [markdown]
# # Data Analytics

# %%
dataset.describe()
# Out:
#                  id          age        click
# count   5234.000000  5234.000000  5234.000000
# mean    5015.464654    40.197363     0.640237
# std     2819.802447    13.126420     0.479977
# min        8.000000    18.000000     0.000000
# 25%     2467.750000    29.000000     0.000000
# 50%     5082.000000    39.500000     1.000000
# 75%     7283.750000    52.000000     1.000000
# max    10000.000000    64.000000     1.000000

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5234 entries, 0 to 9999
# Columns: 4015 entries, id to time_of_day_Night
# dtypes: bool(4012), float64(1), int64(2)
# memory usage: 20.2 MB

# %%
dataset['id'].value_counts()
dataset['age'].value_counts()
dataset['device_type_Tablet'].value_counts()
dataset['ad_position_Side'].value_counts()
dataset['ad_position_Top'].value_counts()
dataset['browsing_history_Entertainment'].value_counts()
dataset['browsing_history_News'].value_counts()
dataset['browsing_history_Shopping'].value_counts()
dataset['browsing_history_Social Media'].value_counts()
dataset['time_of_day_Morning'].value_counts()
dataset['time_of_day_Evening'].value_counts()
dataset['time_of_day_Night'].value_counts()
# Out:
# time_of_day_Night
# False    4194
# True     1040
# Name: count, dtype: int64

# %%
dataset['click'].value_counts(normalize=True)
# Out:
# click
# 1    0.640237
# 0    0.359763
# Name: proportion, dtype: float64

# %%
plt.figure(figsize=(8,6))
sns.histplot(dataset['age'], bins=30, kde=True)
plt.title('Distribution of Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x='click', y='age', data= dataset)
plt.title('Age vs Click Behavior')
plt.xlabel('Click (0 = No, 1 = Yes)')
plt.ylabel('Age')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.countplot(x='device_type_Tablet', hue='click', data=dataset)
plt.title('Click Rate by Device Type')
plt.xlabel('Device Type')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.countplot(x='ad_position_Top',hue='click', data=dataset)
plt.title('Click Rate by Ad Position')
plt.xlabel('Ad Position')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.countplot(x='ad_position_Side',hue='click', data=dataset)
plt.title('Click Rate by Ad Position')
plt.xlabel('Ad Position')
plt.ylabel('Count')
plt.show()

# %%
dataset.groupby('time_of_day_Morning')['click'].mean().plot(kind='bar')
plt.title('Click Rate by Time of Day')
plt.ylabel('Click Rate')
plt.show()

# %%
pd.crosstab(dataset['device_type_Tablet'], dataset['click'], normalize='index').plot(kind='bar', stacked=True)
plt.title('Click Rate by Device Type')
plt.show()
